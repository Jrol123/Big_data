# %%
import pandas as pd

# %%
df = pd.read_csv('2019.csv')
#df.head()
#display(df)
#df.head(12)
#df.tail()
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %%
#excel_data = pd.read_excel('simple.xlsx')
#excel_data.head()

# %%
#df.head()
#display(df)
#df.head(12)
#df.tail()

# %%
my_df1 = pd.DataFrame({'id': [1, 2, 3],
                      'name': ['Bob', 'Alice', 'Scott'],
                      'age': [21, 15, 30]})

my_df2 = pd.DataFrame([[1,'Bob', 21],
                  [2,'Alice', 15],
                  [3,'Scott', 30]], 
columns=['id','name', 'age'])
display(my_df1)

display(my_df2)
# Out:
#    id   name  age
# 0   1    Bob   21
# 1   2  Alice   15
# 2   3  Scott   30
#    id   name  age
# 0   1    Bob   21
# 1   2  Alice   15
# 2   3  Scott   30

# %%
print(df.shape) # размеры сразу по двум осям
print(df.shape[0]) # кол-во строк
print(df.shape[1]) # кол-во столбцов
# Out:
# (156, 9)
# 156
# 9

# %%
df_copy = df.copy()
df_copy
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %%
df.rename(columns = {'Overall rank':'Место в рейтинге', 'Country or region':'Страна или регион', 'Score':'Баллы', 'GDP per capita':'ВВП на душу населения', 'Social support':'Социальная поддержка', 'Healthy life expectancy':'Ожидаемая продолжительность здоровой жизни', 'Freedom to make life choices': 'Свобода жизненных выборов', 'Generosity':  'Щедрость', 'Perceptions of corruption':'Восприятие коррупции' }, inplace = True)
df.head()
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 0                      0.596     0.153                 0.393
# 1                      0.592     0.252                 0.410
# 2                      0.603     0.271                 0.341
# 3                      0.591     0.354                 0.118
# 4                      0.557     0.322                 0.298

# %%
df.describe()
# Out:
#        Место в рейтинге       Баллы  ВВП на душу населения  \
# count        156.000000  156.000000             156.000000
# mean          78.500000    5.407096               0.905147
# std           45.177428    1.113120               0.398389
# min            1.000000    2.853000               0.000000
# 25%           39.750000    4.544500               0.602750
# 50%           78.500000    5.379500               0.960000
# 75%          117.250000    6.184500               1.232500
# max          156.000000    7.769000               1.684000
#
#        Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# count            156.000000                                  156.000000
# mean               1.208814                                    0.725244
# std                0.299191                                    0.242124
# min                0.000000                                    0.000000
# 25%                1.055750                                    0.547750
# 50%                1.271500                                    0.789000
# 75%                1.452500                                    0.881750
# max                1.624000                                    1.141000
#
#        Свобода жизненных выборов    Щедрость  Восприятие коррупции
# count                 156.000000  156.000000            156.000000
# mean                    0.392571    0.184846              0.110603
# std                     0.143289    0.095254              0.094538
# min                     0.000000    0.000000              0.000000
# 25%                     0.308000    0.108750              0.047000
# 50%                     0.417000    0.177500              0.085500
# 75%                     0.507250    0.248250              0.141250
# max                     0.631000    0.566000              0.453000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Место в рейтинге                            156 non-null    int64
#  1   Страна или регион                           156 non-null    object
#  2   Баллы                                       156 non-null    float64
#  3   ВВП на душу населения                       156 non-null    float64
#  4   Социальная поддержка                        156 non-null    float64
#  5   Ожидаемая продолжительность здоровой жизни  156 non-null    float64
#  6   Свобода жизненных выборов                   156 non-null    float64
#  7   Щедрость                                    156 non-null    float64
#  8   Восприятие коррупции                        156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
data_new = df[['Место в рейтинге', 'Ожидаемая продолжительность здоровой жизни']]
data_new.head(5)
# Out:
#    Место в рейтинге  Ожидаемая продолжительность здоровой жизни
# 0                 1                                       0.986
# 1                 2                                       0.996
# 2                 3                                       1.028
# 3                 4                                       1.026
# 4                 5                                       0.999

# %%
df.loc [:, 'Место в рейтинге':'Социальная поддержка']
# Out:
#      Место в рейтинге         Страна или регион  Баллы  ВВП на душу населения  \
# 0                   1                   Finland  7.769                  1.340
# 1                   2                   Denmark  7.600                  1.383
# 2                   3                    Norway  7.554                  1.488
# 3                   4                   Iceland  7.494                  1.380
# 4                   5               Netherlands  7.488                  1.396
# ..                ...                       ...    ...                    ...
# 151               152                    Rwanda  3.334                  0.359
# 152               153                  Tanzania  3.231                  0.476
# 153               154               Afghanistan  3.203                  0.350
# 154               155  Central African Republic  3.083                  0.026
# 155               156               South Sudan  2.853                  0.306
#
#      Социальная поддержка
# 0                   1.587
# 1                   1.573
# 2                   1.582
# 3                   1.624
# 4                   1.522
# ..                    ...
# 151                 0.711
# 152                 0.885
# 153                 0.517
# 154                 0.000
# 155                 0.575
#
# [156 rows x 5 columns]

# %%
# вырезать отдельно строки и столбцы
df.iloc[0:5, 0:3]
# Out:
#    Место в рейтинге Страна или регион  Баллы
# 0                 1           Finland  7.769
# 1                 2           Denmark  7.600
# 2                 3            Norway  7.554
# 3                 4           Iceland  7.494
# 4                 5       Netherlands  7.488

# %%
df['Сумма'] = df['ВВП на душу населения'] + df['Социальная поддержка']
df.head(5)
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции  Сумма
# 0                      0.596     0.153                 0.393  2.927
# 1                      0.592     0.252                 0.410  2.956
# 2                      0.603     0.271                 0.341  3.070
# 3                      0.591     0.354                 0.118  3.004
# 4                      0.557     0.322                 0.298  2.918

# %%
df = df.drop(['Сумма'], axis=1)
df.head(5)
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 0                      0.596     0.153                 0.393
# 1                      0.592     0.252                 0.410
# 2                      0.603     0.271                 0.341
# 3                      0.591     0.354                 0.118
# 4                      0.557     0.322                 0.298

# %%
df = df.drop(df.shape[0]-1, axis=0)
df.tail(5)
# Out:
#      Место в рейтинге         Страна или регион  Баллы  ВВП на душу населения  \
# 150               151                     Yemen  3.380                  0.287
# 151               152                    Rwanda  3.334                  0.359
# 152               153                  Tanzania  3.231                  0.476
# 153               154               Afghanistan  3.203                  0.350
# 154               155  Central African Republic  3.083                  0.026
#
#      Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 150                 1.163                                       0.463
# 151                 0.711                                       0.614
# 152                 0.885                                       0.499
# 153                 0.517                                       0.361
# 154                 0.000                                       0.105
#
#      Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 150                      0.143     0.108                 0.077
# 151                      0.555     0.217                 0.411
# 152                      0.417     0.276                 0.147
# 153                      0.000     0.158                 0.025
# 154                      0.225     0.235                 0.035

# %%
df['Страна или регион'].unique()
# Out:
# array(['Finland', 'Denmark', 'Norway', 'Iceland', 'Netherlands',
#        'Switzerland', 'Sweden', 'New Zealand', 'Canada', 'Austria',
#        'Australia', 'Costa Rica', 'Israel', 'Luxembourg',
#        'United Kingdom', 'Ireland', 'Germany', 'Belgium', 'United States',
#        'Czech Republic', 'United Arab Emirates', 'Malta', 'Mexico',
#        'France', 'Taiwan', 'Chile', 'Guatemala', 'Saudi Arabia', 'Qatar',
#        'Spain', 'Panama', 'Brazil', 'Uruguay', 'Singapore', 'El Salvador',
#        'Italy', 'Bahrain', 'Slovakia', 'Trinidad & Tobago', 'Poland',
#        'Uzbekistan', 'Lithuania', 'Colombia', 'Slovenia', 'Nicaragua',
#        'Kosovo', 'Argentina', 'Romania', 'Cyprus', 'Ecuador', 'Kuwait',
#        'Thailand', 'Latvia', 'South Korea', 'Estonia', 'Jamaica',
#        'Mauritius', 'Japan', 'Honduras', 'Kazakhstan', 'Bolivia',
#        'Hungary', 'Paraguay', 'Northern Cyprus', 'Peru', 'Portugal',
#        'Pakistan', 'Russia', 'Philippines', 'Serbia', 'Moldova', 'Libya',
#        'Montenegro', 'Tajikistan', 'Croatia', 'Hong Kong',
#        'Dominican Republic', 'Bosnia and Herzegovina', 'Turkey',
#        'Malaysia', 'Belarus', 'Greece', 'Mongolia', 'North Macedonia',
#        'Nigeria', 'Kyrgyzstan', 'Turkmenistan', 'Algeria', 'Morocco',
#        'Azerbaijan', 'Lebanon', 'Indonesia', 'China', 'Vietnam', 'Bhutan',
#        'Cameroon', 'Bulgaria', 'Ghana', 'Ivory Coast', 'Nepal', 'Jordan',
#        'Benin', 'Congo (Brazzaville)', 'Gabon', 'Laos', 'South Africa',
#        'Albania', 'Venezuela', 'Cambodia', 'Palestinian Territories',
#        'Senegal', 'Somalia', 'Namibia', 'Niger', 'Burkina Faso',
#        'Armenia', 'Iran', 'Guinea', 'Georgia', 'Gambia', 'Kenya',
#        'Mauritania', 'Mozambique', 'Tunisia', 'Bangladesh', 'Iraq',
#        'Congo (Kinshasa)', 'Mali', 'Sierra Leone', 'Sri Lanka', 'Myanmar',
#        'Chad', 'Ukraine', 'Ethiopia', 'Swaziland', 'Uganda', 'Egypt',
#        'Zambia', 'Togo', 'India', 'Liberia', 'Comoros', 'Madagascar',
#        'Lesotho', 'Burundi', 'Zimbabwe', 'Haiti', 'Botswana', 'Syria',
#        'Malawi', 'Yemen', 'Rwanda', 'Tanzania', 'Afghanistan',
#        'Central African Republic'], dtype=object)

# %%
df['Страна или регион'].value_counts()
# Out:
# Страна или регион
# Finland                     1
# Denmark                     1
# Norway                      1
# Iceland                     1
# Netherlands                 1
#                            ..
# Yemen                       1
# Rwanda                      1
# Tanzania                    1
# Afghanistan                 1
# Central African Republic    1
# Name: count, Length: 155, dtype: int64

# %%
df[df['Страна или регион'] == 'Norway']
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 2                 3            Norway  7.554                  1.488
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 2                 1.582                                       1.028
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 2                      0.603     0.271                 0.341

# %%
df[df['Ожидаемая продолжительность здоровой жизни'] > 1]
# Out:
#     Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 2                  3            Norway  7.554                  1.488
# 3                  4           Iceland  7.494                  1.380
# 5                  6       Switzerland  7.480                  1.452
# 6                  7            Sweden  7.343                  1.387
# 7                  8       New Zealand  7.307                  1.303
# 8                  9            Canada  7.278                  1.365
# 9                 10           Austria  7.246                  1.376
# 10                11         Australia  7.228                  1.372
# 12                13            Israel  7.139                  1.276
# 13                14        Luxembourg  7.090                  1.609
# 23                24            France  6.592                  1.324
# 29                30             Spain  6.354                  1.286
# 33                34         Singapore  6.262                  1.572
# 35                36             Italy  6.223                  1.294
# 48                49            Cyprus  6.046                  1.263
# 53                54       South Korea  5.895                  1.301
# 57                58             Japan  5.886                  1.327
# 63                64   Northern Cyprus  5.718                  1.263
# 75                76         Hong Kong  5.430                  1.438
#
#     Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 2                  1.582                                       1.028
# 3                  1.624                                       1.026
# 5                  1.526                                       1.052
# 6                  1.487                                       1.009
# 7                  1.557                                       1.026
# 8                  1.505                                       1.039
# 9                  1.475                                       1.016
# 10                 1.548                                       1.036
# 12                 1.455                                       1.029
# 13                 1.479                                       1.012
# 23                 1.472                                       1.045
# 29                 1.484                                       1.062
# 33                 1.463                                       1.141
# 35                 1.488                                       1.039
# 48                 1.223                                       1.042
# 53                 1.219                                       1.036
# 57                 1.419                                       1.088
# 63                 1.252                                       1.042
# 75                 1.277                                       1.122
#
#     Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 2                       0.603     0.271                 0.341
# 3                       0.591     0.354                 0.118
# 5                       0.572     0.263                 0.343
# 6                       0.574     0.267                 0.373
# 7                       0.585     0.330                 0.380
# 8                       0.584     0.285                 0.308
# 9                       0.532     0.244                 0.226
# 10                      0.557     0.332                 0.290
# 12                      0.371     0.261                 0.082
# 13                      0.526     0.194                 0.316
# 23                      0.436     0.111                 0.183
# 29                      0.362     0.153                 0.079
# 33                      0.556     0.271                 0.453
# 35                      0.231     0.158                 0.030
# 48                      0.406     0.190                 0.041
# 53                      0.159     0.175                 0.056
# 57                      0.445     0.069                 0.140
# 63                      0.417     0.191                 0.162
# 75                      0.440     0.258                 0.287

# %%
# обработка данных о пассажирах титаника
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.Embarked == 'S'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool

# %%
df.nlargest(5, 'Age')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
df.Age.argmin()
# Out:
# np.int64(803)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 194          195         1       1
# 888          889         0       3
# 316          317         1       2
# 556          557         1       1
# 388          389         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  female  44.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 316                Kantor, Mrs. Sinai (Miriam Sternin)  female  24.0      1
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# 388                               Sadlier, Mr. Matthew    male   NaN      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 194      0    PC 17610  27.7208    B4        C
# 888      2  W./C. 6607  23.4500   NaN        S
# 316      0      244367  26.0000   NaN        S
# 556      0       11755  39.6000   A16        C
# 388      0      367655   7.7292   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# метод .isnull() выдает логический массив, где пропуски обозначены как True
# метод .sum() по умолчанию суммирует эти True или единицы по столбцам (axis = 0)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(labels = 'Cabin', axis = 1, inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.Age.fillna(df.Age.median(), inplace = True)
df
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_4076\1576221538.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Age.fillna(df.Age.median(), inplace = True)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.Embarked.fillna('S', inplace = True)
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_4076\3721393541.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Embarked.fillna('S', inplace = True)

# %%
boxplot = df.boxplot(df.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 boxplot = df.boxplot(df.columns)
#
# File C:\PyInterpreters\BigData\lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)
#     530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# --> 533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#     536         by=by,
#     537         ax=ax,
#     538         fontsize=fontsize,
#     539         rot=rot,
#     540         grid=grid,
#     541         figsize=figsize,
#     542         layout=layout,
#     543         return_type=return_type,
#     544         **kwargs,
#     545     )
#
# File C:\PyInterpreters\BigData\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:492, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     477 def boxplot_frame(
#     478     self,
#     479     column=None,
#    (...)
#     488     **kwds,
#     489 ):
#     490     import matplotlib.pyplot as plt
# --> 492     ax = boxplot(
#     493         self,
#     494         column=column,
#     495         by=by,
#     496         ax=ax,
#     497         fontsize=fontsize,
#     498         grid=grid,
#     499         rot=rot,
#     500         figsize=figsize,
#     501         layout=layout,
#     502         return_type=return_type,
#     503         **kwds,
#     504     )
#     505     plt.draw_if_interactive()
#     506     return ax
#
# File C:\PyInterpreters\BigData\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:469, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     467     columns = data.columns
#     468 else:
# --> 469     data = data[columns]
#     471 result = plot_group(columns, data.values.T, ax, **kwds)
#     472 ax.grid(grid)
#
# File C:\PyInterpreters\BigData\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File C:\PyInterpreters\BigData\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File C:\PyInterpreters\BigData\lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([('PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked')], dtype='object')] are in the [columns]"

# %%
import numpy
from matplotlib import pyplot as plt


def delete_outlines(feature):
    # Визуализация данных  выбросами
    _x = df.boxplot(column=feature)
    plt.close('all')
    # Получение границ усов
    whiskers = []
    for line in _x.lines:
        if line.get_linestyle() == '-':
            whiskers.append(line.get_ydata())

    whiskers = whiskers[1:3]
    lower_whisker = whiskers[0][1]
    upper_whisker = whiskers[1][1]

    median = numpy.median(df[feature])
    return numpy.where((df[feature] > upper_whisker) | (df[feature] < lower_whisker), median, df[feature])

features = ['Age','SibSp', 'Fare']

for f in features:
   df[f] = delete_outlines(f)

# Вывод boxplot для выбранных столбцов
plt.boxplot(df[features].values, whis=(0, 100))

 # Добавление меток осей x
plt.xticks(range(1, len(features) + 1), features)

 # Отображение графика
plt.show()
