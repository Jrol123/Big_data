# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data.xlsx')

df
# Out:
#                       Unnamed: 0     x1      x2     x3     x4     x5   Округ
# 0           Белгородская область  7 777  14 918  2 825  2 009  1 841  сenter
# 1               Брянская область  4 560  10 211  1 538  1 418    837     NaN
# 2           Владимирская область  5 802   8 902  1 703  1 468    NaN  сenter
# 3            Воронежская область    NaN  17 186  3 362  2 458  4 347  сenter
# 4             Ивановская область  4 495   5 649  1 338    977  1 288  сenter
# ..                           ...    ...     ...    ...    ...    ...     ...
# 80              Амурская область  2 954   7 211    929    977    829      dv
# 81           Магаданская область    787   1 215    331    202     97      dv
# 82           Сахалинская область  3 332   4 511    792    507    131      dv
# 83  Еврейская автономная область    803     NaN    175    187     57      dv
# 84    Чукотский автономный округ    292     713    179     36      2      dv
#
# [85 rows x 7 columns]

# %%
df.iloc[:, 1: 6] = df.iloc[:, 1: 6].applymap(lambda x: str(x).replace('\xa0', ''))

df.x1.astype(float)
df
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1463173323.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.iloc[:, 1: 6] = df.iloc[:, 1: 6].applymap(lambda x: str(x).replace('\xa0', ''))
#                       Unnamed: 0    x1     x2    x3    x4    x5   Округ
# 0           Белгородская область  7777  14918  2825  2009  1841  сenter
# 1               Брянская область  4560  10211  1538  1418   837     NaN
# 2           Владимирская область  5802   8902  1703  1468   nan  сenter
# 3            Воронежская область   nan  17186  3362  2458  4347  сenter
# 4             Ивановская область  4495   5649  1338   977  1288  сenter
# ..                           ...   ...    ...   ...   ...   ...     ...
# 80              Амурская область  2954   7211   929   977   829      dv
# 81           Магаданская область   787   1215   331   202    97      dv
# 82           Сахалинская область  3332   4511   792   507   131      dv
# 83  Еврейская автономная область   803    nan   175   187    57      dv
# 84    Чукотский автономный округ   292    713   179    36     2      dv
#
# [85 rows x 7 columns]

# %%
df.iloc[:, 1: 6] = df.iloc[:, 1: 6].applymap(lambda x: pd.to_numeric(x, 'coerce'))

df
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1008739198.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.iloc[:, 1: 6] = df.iloc[:, 1: 6].applymap(lambda x: pd.to_numeric(x, 'coerce'))
#                       Unnamed: 0      x1       x2      x3      x4      x5  \
# 0           Белгородская область  7777.0  14918.0  2825.0  2009.0  1841.0
# 1               Брянская область  4560.0  10211.0  1538.0  1418.0   837.0
# 2           Владимирская область  5802.0   8902.0  1703.0  1468.0     NaN
# 3            Воронежская область     NaN  17186.0  3362.0  2458.0  4347.0
# 4             Ивановская область  4495.0   5649.0  1338.0   977.0  1288.0
# ..                           ...     ...      ...     ...     ...     ...
# 80              Амурская область  2954.0   7211.0   929.0   977.0   829.0
# 81           Магаданская область   787.0   1215.0   331.0   202.0    97.0
# 82           Сахалинская область  3332.0   4511.0   792.0   507.0   131.0
# 83  Еврейская автономная область   803.0      NaN   175.0   187.0    57.0
# 84    Чукотский автономный округ   292.0    713.0   179.0    36.0     2.0
#
#      Округ
# 0   сenter
# 1      NaN
# 2   сenter
# 3   сenter
# 4   сenter
# ..     ...
# 80      dv
# 81      dv
# 82      dv
# 83      dv
# 84      dv
#
# [85 rows x 7 columns]

# %%
for name in ['x1', 'x2', 'x3', 'x4', 'x5']:
    df[name].fillna(df[name].median(), inplace=True)

df
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[name].fillna(df[name].median(), inplace=True)
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\1291756577.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[name].fillna(df[name].median(), inplace=True)
#                       Unnamed: 0      x1       x2      x3      x4      x5  \
# 0           Белгородская область  7777.0  14918.0  2825.0  2009.0  1841.0
# 1               Брянская область  4560.0  10211.0  1538.0  1418.0   837.0
# 2           Владимирская область  5802.0   8902.0  1703.0  1468.0  1169.0
# 3            Воронежская область  5562.0  17186.0  3362.0  2458.0  4347.0
# 4             Ивановская область  4495.0   5649.0  1338.0   977.0  1288.0
# ..                           ...     ...      ...     ...     ...     ...
# 80              Амурская область  2954.0   7211.0   929.0   977.0   829.0
# 81           Магаданская область   787.0   1215.0   331.0   202.0    97.0
# 82           Сахалинская область  3332.0   4511.0   792.0   507.0   131.0
# 83  Еврейская автономная область   803.0   9825.0   175.0   187.0    57.0
# 84    Чукотский автономный округ   292.0    713.0   179.0    36.0     2.0
#
#      Округ
# 0   сenter
# 1      NaN
# 2   сenter
# 3   сenter
# 4   сenter
# ..     ...
# 80      dv
# 81      dv
# 82      dv
# 83      dv
# 84      dv
#
# [85 rows x 7 columns]

# %%
frequent_pl = df['Округ'].value_counts().head(1).index.name

# %%
df['Округ'].fillna(frequent_pl, inplace=True)
# Out:
# C:\Users\artem\AppData\Local\Temp\ipykernel_12688\3701515529.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Округ'].fillna(frequent_pl, inplace=True)

# %%
df
# Out:
#                       Unnamed: 0      x1       x2      x3      x4      x5  \
# 0           Белгородская область  7777.0  14918.0  2825.0  2009.0  1841.0
# 1               Брянская область  4560.0  10211.0  1538.0  1418.0   837.0
# 2           Владимирская область  5802.0   8902.0  1703.0  1468.0  1169.0
# 3            Воронежская область  5562.0  17186.0  3362.0  2458.0  4347.0
# 4             Ивановская область  4495.0   5649.0  1338.0   977.0  1288.0
# ..                           ...     ...      ...     ...     ...     ...
# 80              Амурская область  2954.0   7211.0   929.0   977.0   829.0
# 81           Магаданская область   787.0   1215.0   331.0   202.0    97.0
# 82           Сахалинская область  3332.0   4511.0   792.0   507.0   131.0
# 83  Еврейская автономная область   803.0   9825.0   175.0   187.0    57.0
# 84    Чукотский автономный округ   292.0    713.0   179.0    36.0     2.0
#
#      Округ
# 0   сenter
# 1    Округ
# 2   сenter
# 3   сenter
# 4   сenter
# ..     ...
# 80      dv
# 81      dv
# 82      dv
# 83      dv
# 84      dv
#
# [85 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# x1            0
# x2            0
# x3            0
# x4            0
# x5            0
# Округ         0
# dtype: int64

# %%
df
# Out:
#                       Unnamed: 0      x1       x2      x3      x4      x5  \
# 0           Белгородская область  7777.0  14918.0  2825.0  2009.0  1841.0
# 1               Брянская область  4560.0  10211.0  1538.0  1418.0   837.0
# 2           Владимирская область  5802.0   8902.0  1703.0  1468.0  1169.0
# 3            Воронежская область  5562.0  17186.0  3362.0  2458.0  4347.0
# 4             Ивановская область  4495.0   5649.0  1338.0   977.0  1288.0
# ..                           ...     ...      ...     ...     ...     ...
# 80              Амурская область  2954.0   7211.0   929.0   977.0   829.0
# 81           Магаданская область   787.0   1215.0   331.0   202.0    97.0
# 82           Сахалинская область  3332.0   4511.0   792.0   507.0   131.0
# 83  Еврейская автономная область   803.0   9825.0   175.0   187.0    57.0
# 84    Чукотский автономный округ   292.0    713.0   179.0    36.0     2.0
#
#      Округ
# 0   сenter
# 1    Округ
# 2   сenter
# 3   сenter
# 4   сenter
# ..     ...
# 80      dv
# 81      dv
# 82      dv
# 83      dv
# 84      dv
#
# [85 rows x 7 columns]

# %%
df.iloc[:, 1: 6]
# Out:
#         x1       x2      x3      x4      x5
# 0   7777.0  14918.0  2825.0  2009.0  1841.0
# 1   4560.0  10211.0  1538.0  1418.0   837.0
# 2   5802.0   8902.0  1703.0  1468.0  1169.0
# 3   5562.0  17186.0  3362.0  2458.0  4347.0
# 4   4495.0   5649.0  1338.0   977.0  1288.0
# ..     ...      ...     ...     ...     ...
# 80  2954.0   7211.0   929.0   977.0   829.0
# 81   787.0   1215.0   331.0   202.0    97.0
# 82  3332.0   4511.0   792.0   507.0   131.0
# 83   803.0   9825.0   175.0   187.0    57.0
# 84   292.0    713.0   179.0    36.0     2.0
#
# [85 rows x 5 columns]

# %%
df.columns[1:6]
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5'], dtype='object')

# %%
features = df.columns[1: 6]
# ['x1', 'x2', 'x3', 'x4', 'x5']

# %%
plt.boxplot(df[features].values)

plt.show()

# %%
def get_whiskers(dataframe: pd.DataFrame, feature: str):
    # Визуализация данных выбросами
    _x = dataframe.boxplot(column=feature)
    plt.close('all')
    # Получение границ усов
    whiskers = []
    for line in _x.lines:
        if line.get_linestyle() == '-':
            whiskers.append(line.get_ydata())

    whiskers = whiskers[1:3]
    lower_whisker = whiskers[0][1]
    upper_whisker = whiskers[1][1]

    return lower_whisker, upper_whisker

# %%
def delete_outlines(dataframe: pd.DataFrame, feature):
    lw, uw = get_whiskers(dataframe, feature)

    median = np.median(df[feature]) # По-стандарту, выбросы заменяются на медианные значения (если, конечно, выбросов не слишком много. Тогда уже всё плохо и нужно брать другую выборку)
    return np.where((df[feature] > uw) | (df[feature] < lw), median, df[feature])

# %%
for f in features:
    df[f] = delete_outlines(df, f)

# Вывод boxplot для выбранных столбцов
plt.boxplot(df[features].values, whis=(0, 100))

# Добавление меток осей x
plt.xticks(range(1, len(features) + 1), features)

# Отображение графика
plt.show()
